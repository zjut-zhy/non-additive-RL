# %%
import argparse
import errno
import os
import random
from importlib.metadata import requires
from timeit import timeit
import dill as pickle
import numpy as np
import scipy
import torch
import wandb
import yaml
from sympy import Matrix, MatrixSymbol, derive_by_array, symarray
from torch.distributions import Categorical

from subrl.utils.environment import GridWorld
from subrl.utils.network import append_state
from subrl.utils.network import policy as agent_net
from visualization import Visu

# TODO: 1. remove dependence from matrix and could run multiple times in parallel, .sh script, run it on the server, check how to plot multiple on wb,
# can it plot different kappa's on the same with grouping
# apply a policy gradient algorithm, since the policy is deterministic, use policy iteration/value iteration since we know the dynamics
#
workspace = "subrl"

# 1) Load the config file
with open(workspace + "/params/" + "two_rooms/subrl_NM" + ".yaml") as file:
    params = yaml.load(file, Loader=yaml.FullLoader)
print(params)

# 2) Set the path and copy params from file
env_load_path = workspace + \
    "/environments/" + params["env"]["node_weight"]+ "/env_" + \
    str(1)

params['env']['num'] = 1 

epochs = params["alg"]["epochs"]

H = params["env"]["horizon"]
MAX_Ret = 2*(H+1)
if params["env"]["disc_size"] == "large":
    MAX_Ret = 3*(H+2)

# 3) Setup the environement
env = GridWorld(
    env_params=params["env"], common_params=params["common"], visu_params=params["visu"], env_file_path=env_load_path)
node_size = params["env"]["shape"]['x']*params["env"]["shape"]['y']

if params["env"]["node_weight"] == "entropy" or params["env"]["node_weight"] == "steiner_covering" or params["env"]["node_weight"] == "GP": 
    a_file = open(env_load_path +".pkl", "rb")
    data = pickle.load(a_file)
    a_file.close()

if params["env"]["node_weight"] == "entropy":
    env.cov = data
if params["env"]["node_weight"] == "steiner_covering":
    env.items_loc = data
if params["env"]["node_weight"] == "GP":
    env.weight = data

visu = Visu(env_params=params["env"])

env.get_horizon_transition_matrix()
# Out:
# {'env': {'start': 1, 'step_size': 0.1, 'shape': {'x': 7, 'y': 14}, 'horizon': 40, 'node_weight': 'constant', 'disc_size': 'small', 'n_players': 3, 'Cx_lengthscale': 2, 'Cx_noise': 0.001, 'Fx_lengthscale': 1, 'Fx_noise': 0.001, 'Cx_beta': 1.5, 'Fx_beta': 1.5, 'generate': False, 'env_file_name': 'env_data.pkl', 'cov_module': 'Matern', 'stochasticity': 0.0, 'domains': 'two_room'}, 'alg': {'gamma': 1, 'type': 'NM', 'ent_coef': 0.0, 'epochs': 140, 'lr': 0.02}, 'common': {'a': 1, 'subgrad': 'greedy', 'grad': 'pytorch', 'algo': 'both', 'init': 'deterministic', 'batch_size': 3000}, 'visu': {'wb': 'disabled', 'a': 1}}
# x_ticks [-0.5001, -0.4999, 0.4999, 0.5001, 1.4999, 1.5001, 2.4999, 2.5001, 3.4999, 3.5001, 4.4999, 4.5001, 5.4999, 5.5001, 6.4999, 6.5001, 7.4999, 7.5001, 8.4999, 8.5001, 9.4999, 9.5001, 10.4999, 10.5001, 11.4999, 11.5001, 12.4999, 12.5001, 13.4999, 13.5001]
# y_ticks [-0.5001, -0.4999, 0.4999, 0.5001, 1.4999, 1.5001, 2.4999, 2.5001, 3.4999, 3.5001, 4.4999, 4.5001, 5.4999, 5.5001, 6.4999, 6.5001]

# %%
def train():
    # Agent's policy
    if params["alg"]["type"]=="M" or params["alg"]["type"]=="SRL":
        agent = agent_net(2, env.action_dim)
    else:
        agent = agent_net(H-1, env.action_dim)
    optim = torch.optim.Adam(agent.parameters(), lr=params["alg"]["lr"])

    for t_eps in range(epochs):
        mat_action = []
        mat_state = []
        mat_return = []
        marginal_return = []
        mat_done = []
        # print(t_eps)
        env.initialize()
        mat_state.append(env.state)
        init_state = env.state
        list_batch_state = []
        for h_iter in range(H-1):
            if params["alg"]["type"]=="M" or params["alg"]["type"]=="SRL":
                batch_state = mat_state[-1].reshape(-1, 1).float()
                # append time index to the state
                batch_state = torch.cat(
                    [batch_state, h_iter*torch.ones_like(batch_state)], 1)
            else:
                batch_state = append_state(mat_state, H-1)
            action_prob = agent(batch_state)
            policy_dist = Categorical(action_prob)
            actions = policy_dist.sample()
            mat_action.append(actions)
            env.step(h_iter, actions)
            mat_state.append(env.state)  # s+1
            mat_return.append(env.weighted_traj_return(mat_state, type = params["alg"]["type"]))
            if h_iter ==0:
                marginal_return.append(mat_return[h_iter])
            else:
                marginal_return.append(mat_return[h_iter] - mat_return[h_iter-1])
            list_batch_state.append(batch_state)

        ###################
        # Compute gradients
        ###################

        states_visited = torch.vstack(list_batch_state).float()
    
        policy_dist = Categorical(agent(states_visited))
        log_prob = policy_dist.log_prob(torch.hstack(mat_action))
        batch_return = torch.hstack(marginal_return)/MAX_Ret

        # - 2*policy_dist.entropy().mean()
        J_obj = -1*(torch.mean(log_prob*batch_return) + params["alg"]["ent_coef"] *
                    policy_dist.entropy().mean()/(t_eps+1))
        optim.zero_grad()
        J_obj.backward()
        optim.step()

        obj = env.weighted_traj_return(mat_state).float()
        print(visu.JPi_optimal, " mean ", obj.mean(), " max ",
            obj.max(), " median ", obj.median(), " min ", obj.min(), " ent ", policy_dist.entropy().mean().detach())
    return agent

# %%
min_return = []
max_return = []
mean_return = []
median_return = []
for iter in range(10):
    # params["common"]["batch_size"]=1000
    agent = train()
    mat_state = []
    mat_return = []
    env.initialize()
    mat_state.append(env.state)
    init_state = env.state
    for h_iter in range(H-1):
        batch_state = append_state(mat_state, H-1)
        action_prob = agent(batch_state)
        policy_dist = Categorical(action_prob)
        actions = policy_dist.sample()
        env.step(h_iter, actions)
        mat_state.append(env.state)  # s+1

    returns = env.weighted_traj_return(mat_state, type = params["alg"]["type"]).float()
    min_return.append(returns.min())
    max_return.append(returns.max())
    mean_return.append(returns.mean())
    median_return.append(returns.median())
mean_min_return = np.mean(min_return)
std_min_return = np.std(min_return)
mean_max_return = np.mean(max_return)
std_max_return = np.std(max_return)
mean_mean_return = np.mean(mean_return)
std_mean_return = np.std(mean_return)
mean_median_return = np.mean(median_return)
std_median_return = np.std(median_return)
print(f"min: {mean_min_return:.2f}±{std_min_return:.2f}, max: {mean_max_return:.2f}±{std_max_return:.2f}, mean: {mean_mean_return:.2f}±{std_mean_return:.2f}, median: {mean_median_return:.2f}±{std_median_return:.2f}")
# Out:
# None  mean  tensor(18.8360)  max  tensor(33.)  median  tensor(20.)  min  tensor(6.)  ent  tensor(1.5493)
# None  mean  tensor(22.3720)  max  tensor(34.)  median  tensor(22.)  min  tensor(14.)  ent  tensor(1.2196)
# None  mean  tensor(24.1693)  max  tensor(35.)  median  tensor(24.)  min  tensor(11.)  ent  tensor(1.2411)
# None  mean  tensor(25.8920)  max  tensor(36.)  median  tensor(26.)  min  tensor(8.)  ent  tensor(1.2206)
# None  mean  tensor(27.7177)  max  tensor(50.)  median  tensor(27.)  min  tensor(14.)  ent  tensor(1.1722)
# None  mean  tensor(31.2220)  max  tensor(49.)  median  tensor(30.)  min  tensor(14.)  ent  tensor(1.0043)
# None  mean  tensor(32.5220)  max  tensor(48.)  median  tensor(34.)  min  tensor(14.)  ent  tensor(0.8255)
# None  mean  tensor(33.1043)  max  tensor(48.)  median  tensor(35.)  min  tensor(14.)  ent  tensor(0.7269)
# None  mean  tensor(34.6487)  max  tensor(49.)  median  tensor(36.)  min  tensor(14.)  ent  tensor(0.7169)
# None  mean  tensor(36.8723)  max  tensor(50.)  median  tensor(39.)  min  tensor(16.)  ent  tensor(0.7449)
# None  mean  tensor(37.7263)  max  tensor(50.)  median  tensor(40.)  min  tensor(15.)  ent  tensor(0.7570)
# None  mean  tensor(38.6937)  max  tensor(50.)  median  tensor(40.)  min  tensor(14.)  ent  tensor(0.7122)
# None  mean  tensor(38.6647)  max  tensor(50.)  median  tensor(40.)  min  tensor(15.)  ent  tensor(0.6458)
# None  mean  tensor(38.7830)  max  tensor(50.)  median  tensor(40.)  min  tensor(18.)  ent  tensor(0.5792)
# None  mean  tensor(39.1667)  max  tensor(48.)  median  tensor(40.)  min  tensor(18.)  ent  tensor(0.5777)
# None  mean  tensor(38.8930)  max  tensor(49.)  median  tensor(41.)  min  tensor(22.)  ent  tensor(0.6100)
# None  mean  tensor(38.0977)  max  tensor(49.)  median  tensor(40.)  min  tensor(20.)  ent  tensor(0.5794)
# None  mean  tensor(38.6170)  max  tensor(48.)  median  tensor(40.)  min  tensor(19.)  ent  tensor(0.5047)
# None  mean  tensor(38.9657)  max  tensor(48.)  median  tensor(40.)  min  tensor(21.)  ent  tensor(0.5102)
# None  mean  tensor(36.0070)  max  tensor(46.)  median  tensor(38.)  min  tensor(23.)  ent  tensor(0.5579)
# None  mean  tensor(35.8370)  max  tensor(47.)  median  tensor(39.)  min  tensor(20.)  ent  tensor(0.5283)
# None  mean  tensor(34.3473)  max  tensor(48.)  median  tensor(32.)  min  tensor(21.)  ent  tensor(0.5120)
# None  mean  tensor(32.9647)  max  tensor(46.)  median  tensor(31.)  min  tensor(20.)  ent  tensor(0.4947)
# None  mean  tensor(32.1917)  max  tensor(45.)  median  tensor(28.)  min  tensor(21.)  ent  tensor(0.4747)
# None  mean  tensor(31.5393)  max  tensor(47.)  median  tensor(28.)  min  tensor(20.)  ent  tensor(0.4495)
# None  mean  tensor(30.7703)  max  tensor(46.)  median  tensor(28.)  min  tensor(20.)  ent  tensor(0.4168)
# None  mean  tensor(30.1327)  max  tensor(44.)  median  tensor(28.)  min  tensor(20.)  ent  tensor(0.3978)
# None  mean  tensor(29.7363)  max  tensor(44.)  median  tensor(28.)  min  tensor(20.)  ent  tensor(0.3800)
# None  mean  tensor(28.9497)  max  tensor(44.)  median  tensor(28.)  min  tensor(22.)  ent  tensor(0.3724)
# None  mean  tensor(28.7100)  max  tensor(42.)  median  tensor(28.)  min  tensor(20.)  ent  tensor(0.3679)
# None  mean  tensor(28.6483)  max  tensor(44.)  median  tensor(28.)  min  tensor(20.)  ent  tensor(0.
)  median  tensor(30.)  min  tensor(22.)  ent  tensor(0.4650)
# None  mean  tensor(30.8733)  max  tensor(47.)  median  tensor(30.)  min  tensor(22.)  ent  tensor(0.4873)
# None  mean  tensor(31.0287)  max  tensor(48.)  median  tensor(30.)  min  tensor(22.)  ent  tensor(0.5152)
# None  mean  tensor(31.2110)  max  tensor(49.)  median  tensor(30.)  min  tensor(24.)  ent  tensor(0.5323)
# None  mean  tensor(16.9950)  max  tensor(36.)  median  tensor(16.)  min  tensor(6.)  ent  tensor(1.5599)
# None  mean  tensor(24.4307)  max  tensor(38.)  median  tensor(24.)  min  tensor(12.)  ent  tensor(1.2680)
# None  mean  tensor(22.4803)  max  tensor(37.)  median  tensor(22.)  min  tensor(16.)  ent  tensor(1.0371)
# None  mean  tensor(21.4260)  max  tensor(31.)  median  tensor(21.)  min  tensor(18.)  ent  tensor(0.9302)
# None  mean  tensor(21.3807)  max  tensor(30.)  median  tensor(21.)  min  tensor(17.)  ent  tensor(0.8878)
# None  mean  tensor(21.6423)  max  tensor(32.)  median  tensor(22.)  min  tensor(15.)  ent  tensor(0.8757)
# None  mean  tensor(22.2777)  max  tensor(33.)  median  tensor(22.)  min  tensor(19.)  ent  tensor(0.9150)
# None  mean  tensor(23.8137)  max  tensor(35.)  median  tensor(24.)  min  tensor(19.)  ent  tensor(0.9498)
# None  mean  tensor(25.9950)  max  tensor(36.)  median  tensor(26.)  min  tensor(16.)  ent  tensor(0.9655)
# None  mean  tensor(27.0973)  max  tensor(36.)  median  tensor(27.)  min  tensor(8.)  ent  tensor(0.9388)
# None  mean  tensor(25.5590)  max  tensor(34.)  median  tensor(26.)  min  tensor(8.)  ent  tensor(0.8565)
# None  mean  tensor(25.3587)  max  tensor(35.)  median  tensor(26.)  min  tensor(13.)  ent  tensor(0.8362)
# None  mean  tensor(25.5940)  max  tensor(44.)  median  tensor(26.)  min  tensor(13.)  ent  tensor(0.8709)
# None  mean  tensor(26.8557)  max  tensor(46.)  median  tensor(26.)  min  tensor(13.)  ent  tensor(0.8525)
# None  mean  tensor(28.8293)  max  tensor(46.)  median  tensor(27.)  min  tensor(12.)  ent  tensor(0.7706)
# None  mean  tensor(30.4867)  max  tensor(46.)  median  tensor(30.)  min  tensor(16.)  ent  tensor(0.6983)
# None  mean  tensor(32.1533)  max  tensor(46.)  median  tensor(33.)  min  tensor(15.)  ent  tensor(0.6659)
# None  mean  tensor(34.2077)  max  tensor(49.)  median  tensor(36.)  min  tensor(15.)  ent  tensor(0.6527)
# None  mean  tensor(35.5743)  max  tensor(47.)  median  tensor(38.)  min  tensor(11.)  ent  tensor(0.6492)
# None  mean  tensor(36.9193)  max  tensor(48.)  median  tensor(39.)  min  tensor(13.)  ent  tensor(0.6408)
# None  mean  tensor(37.1380)  max  tensor(46.)  median  tensor(39.)  min  tensor(14.)  ent  tensor(0.6183)
# None  mean  tensor(36.0497)  max  tensor(51.)  median  tensor(38.)  min  tensor(12.)  ent  tensor(0.5836)
# None  mean  tensor(33.6507)  max  tensor(45.)  median  tensor(36.)  min  tensor(13.)  ent  tensor(0.5462)
# None  mean  tensor(32.3103)  max  tensor(45.)  median  tensor(33.)  min  tensor(11.)  ent  tensor(0.5308)
# None  mean  tensor(31.8227)  max  tensor(42.)  median  tensor(33.)  min  tensor(13.)  ent  tensor(0.5204)
# None  mean  tensor(31.2070)  max  tensor(41.)  median  tensor(32.)  min  tensor(11.)  ent  tensor(0.5090)
# None  mean  tensor(30.8550)  max  tensor(40.)  median  tensor(32.)  min  tensor(11.)  ent  tensor(0.4947)
# None  mean  tensor(30.6870)  max  tensor(39.)  median  tensor(32.)  min  tensor(13.)  ent  tensor(0.4871)
# None  mean  tensor(30.6180)  max  tensor(39.)  median  tensor(32.)  min  tensor(12.)  ent  tensor(0.4865)
# None  mean  tensor(30.9010)  max  tensor(39.)  median  tensor(32.)  min  tensor(11.)  ent  tensor(0.4816)
# None  mean  tensor(30.8237)  max  tensor(43.)  median  tensor(32.)  min  tensor(12.)  ent  tensor(0.4662)
# None  mean  tensor(31.5187)  max  tensor(41.)  median  tensor(33.)  min  tensor(12.)  ent  tensor(0.4480)
# None  mean  tensor(32.4207)  max  tensor(42.)  median  tensor(34.)  min  tensor(11.)  ent  tensor(0.4353)
# None  mean  tensor(33.5957)  max  tensor(41.)  median  tensor(36.)  min  tensor(11.)  ent  tensor(0.4443)
# None  mean  tensor(35.1593)  max  tensor(44.)  median  tensor(37.)  min  tensor(14.)  ent  tensor(0.4735)
# None  mean  tensor(36.1487)  max  tensor(44.)  median  tensor(37.)  min  tensor(12.)  ent  tensor(0.4970)
# None  mean  tensor(36.9333)  max  tensor(44.)  median  tensor(38.)  min  tensor(15.)  ent  tensor(0.5011)
# None  mean  tensor(37.2153)  max  tensor(44.)  median  tensor(38.)  min  tensor(17.)  ent  tensor(0.4562)
# None  mean  tensor(36.9230)  max  tensor(45.)  median  tensor(38.)  min  tensor(14.)  ent  tensor(0.4191)
# None  mean  tensor(37.0837)  max  tensor(44.)  median  tensor(38.)  min  tensor(19.)  ent  tensor(0.4112)
# None  mean  tensor(37.1667)  max  tensor(46.)  median  tensor(38.)  min  tensor(18.)  ent  tensor(0.4231)
# None  mean  tensor(37.6987)  max  tensor(44.)  median  tensor(38.)  min  tensor(19.)  ent  tensor(0.4459)
# None  mean  tensor(37.8603)  max  tensor(45.)  median  tensor(39.)  min  tensor(23.)  ent  tensor(0.4651)
# None  mean  tensor(38.0310)  max  tensor(47.)  median  tensor(39.)  min  tensor(20.)  ent  tensor(0.4664)
# None  mean  tensor(37.6827)  max  tensor(45.)  median  tensor(40.)  min  tensor(17.)  ent  tensor(0.4704)
# None  mean  tensor(36.3287)  max  tensor(46.)  median  tensor(39.)  min  tensor(20.)  ent  tensor(0.4843)
# None  mean  tensor(34.3673)  max  tensor(44.)  median  tensor(32.)  min  tensor(20.)  ent  tensor(0.4794)
# None  mean  tensor(34.7130)  max  tensor(47.)  median  tensor(32.)  min  tensor(20.)  ent  tensor(0.4749)
# None  mean  tensor(33.6763)  max  tensor(46.)  median  tensor(31.)  min  tensor(19.)  ent  tensor(0.4617)
# None  mean  tensor(32.1177)  max  tensor(45.)  median  tensor(31.)  min  tensor(18.)  ent  tensor(0.4045)
# None  mean  tensor(30.7230)  max  tensor(45.)  median  tensor(31.)  min  tensor(19.)  ent  tensor(0.3147)
# None  mean  tensor(31.2307)  max  tensor(44.)  median  tensor(31.)  min  tensor(20.)  ent  tensor(0.3064)
# None  mean  tensor(31.6243)  max  tensor(45.)  median  tensor(32.)  min  tensor(18.)  ent  tensor(0.3199)
# None  mean  tensor(31.7213)  max  tensor(45.)  median  tensor(32.)  min  tensor(20.)  ent  tensor(0.3005)
# None  mean  tensor(31.3843)  max  tensor(45.)  median  tensor(32.)  min  tensor(18.)  ent  tensor(0.2213)
# None  mean  tensor(31.0433)  max  tensor(44.)  median  tensor(32.)  min  tensor(18.)  ent  tensor(0.1629)
# None  mean  tensor(30.9407)  max  tensor(44.)  median  tensor(32.)  min  tensor(19.)  ent  tensor(0.1209)
# None  mean  tensor(30.3233)  max  tensor(44.)  median  tensor(32.)  min  tensor(18.)  ent  tensor(0.0995)
# None  mean  tensor(28.5830)  max  tensor(41.)  median  tensor(26.)  min  tensor(19.)  ent  tensor(0.0898)
# None  mean  tensor(27.3810)  max  tensor(41.)  median  tensor(26.)  min  tensor(20.)  ent  tensor(0.0846)
# None  mean  tensor(27.6190)  max  tensor(42.)  median  tensor(26.)  min  tensor(22.)  ent  tensor(0.0836)
# None  mean  tensor(27.7247)  max  tensor(40.)  median  tensor(26.)  min  tensor(22.)  ent  tensor(0.0881)
# None  mean  tensor(28.1883)  max  tensor(40.)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0.0957)
# None  mean  tensor(29.1173)  max  tensor(40.)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0.1057)
# None  mean  tensor(29.6440)  max  tensor(40.)  median  tensor(26.)  min  tensor(20.)  ent  tensor(0.1183)
# None  mean  tensor(29.6503)  max  tensor(42.)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0.1302)
# None  mean  tensor(29.7820)  max  tensor(41.)  median  tensor(29.)  min  tensor(20.)  ent  tensor(0.1465)
# None  mean  tensor(29.6310)  max  tensor(42.)  median  tensor(29.)  min  tensor(20.)  ent  tensor(0.1616)
# None  mean  tensor(29.6213)  max  tensor(41.)  median  tensor(30.)  min  tensor(22.)  ent  tensor(0.1746)
# None  mean  tensor(29.6523)  max  tensor(44.)  median  tensor(32.)  min  tensor(18.)  ent  tensor(0.1700)
# None  mean  tensor(29.9093)  max  tensor(41.)  median  tensor(32.)  min  tensor(23.)  ent  tensor(0.1693)
# None  mean  tensor(30.2350)  max  tensor(40.)  median  tensor(32.)  min  tensor(22.)  ent  tensor(0.2149)
# None  mean  tensor(30.4257)  max  tensor(44.)  median  tensor(32.)  min  tensor(18.)  ent  tensor(0.2090)
# None  mean  tensor(30.4883)  max  tensor(44.)  median  tensor(32.)  min  tensor(22.)  ent  tensor(0.2041)
# None  mean  tensor(30.3963)  max  tensor(40.)  median  tensor(32.)  min  tensor(22.)  ent  tensor(0.1179)
# None  mean  tensor(30.2550)  max  tensor(40.)  median  tensor(32.)  min  tensor(19.)  ent  tensor(0.0614)
# None  mean  tensor(30.1083)  max  tensor(40.)  median  tensor(32.)  min  tensor(22.)  ent  tensor(0.0453)
# None  mean  tensor(29.9140)  max  tensor(40.)  median  tensor(32.)  min  tensor(20.)  ent  tensor(0.0373)
# None  mean  tensor(29.7643)  max  tensor(40.)  median  tensor(32.)  min  tensor(20.)  ent  tensor(0.0350)
# None  mean  tensor(27.8547)  max  tensor(40.)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0.0405)
# None  mean  tensor(26.8810)  max  tensor(40.)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0.0361)
# None  mean  tensor(26.7747)  max  tensor(40.)  median  tensor(26.)  min  tensor(20.)  ent  tensor(0.0357)
# None  mean  tensor(26.6390)  max  tensor(40.)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0.0339)
# None  mean  tensor(26.6537)  max  tensor(40.)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0
)  median  tensor(32.)  min  tensor(22.)  ent  tensor(0.0479)
# None  mean  tensor(30.6650)  max  tensor(40.)  median  tensor(32.)  min  tensor(23.)  ent  tensor(0.0492)
# None  mean  tensor(30.3730)  max  tensor(40.)  median  tensor(32.)  min  tensor(22.)  ent  tensor(0.0502)
# None  mean  tensor(29.3347)  max  tensor(40.)  median  tensor(30.)  min  tensor(20.)  ent  tensor(0.0603)
# None  mean  tensor(30.2853)  max  tensor(40.)  median  tensor(32.)  min  tensor(22.)  ent  tensor(0.0567)
# None  mean  tensor(29.9470)  max  tensor(39.)  median  tensor(32.)  min  tensor(20.)  ent  tensor(0.0577)
# None  mean  tensor(29.5737)  max  tensor(42.)  median  tensor(29.)  min  tensor(20.)  ent  tensor(0.0618)
# None  mean  tensor(27.5987)  max  tensor(40.)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0.0549)
# None  mean  tensor(26.5757)  max  tensor(40.)  median  tensor(26.)  min  tensor(22.)  ent  tensor(0.0484)
# None  mean  tensor(26.3540)  max  tensor(40.)  median  tensor(26.)  min  tensor(23.)  ent  tensor(0.0470)
# None  mean  tensor(26.2470)  max  tensor(40.)  median  tensor(26.)  min  tensor(23.)  ent  tensor(0.0448)
# None  mean  tensor(26.2747)  max  tensor(40.)  median  tensor(26.)  min  tensor(22.)  ent  tensor(0.0448)
# None  mean  tensor(26.1837)  max  tensor(39.)  median  tensor(26.)  min  tensor(22.)  ent  tensor(0.0453)
# None  mean  tensor(26.2303)  max  tensor(41.)  median  tensor(26.)  min  tensor(24.)  ent  tensor(0.0482)
# None  mean  tensor(26.2483)  max  tensor(40.)  median  tensor(26.)  min  tensor(23.)  ent  tensor(0.0491)
# None  mean  tensor(26.1583)  max  tensor(39.)  median  tensor(26.)  min  tensor(22.)  ent  tensor(0.0477)
# None  mean  tensor(26.1983)  max  tensor(40.)  median  tensor(26.)  min  tensor(21.)  ent  tensor(0.0505)
# None  mean  tensor(26.2093)  max  tensor(40.)  median  tensor(26.)  min  tensor(21.)  ent  tensor(0.0512)
# None  mean  tensor(26.2233)  max  tensor(40.)  median  tensor(26.)  min  tensor(21.)  ent  tensor(0.0520)
# None  mean  tensor(26.1967)  max  tensor(41.)  median  tensor(26.)  min  tensor(21.)  ent  tensor(0.0514)
# None  mean  tensor(26.2443)  max  tensor(40.)  median  tensor(26.)  min  tensor(21.)  ent  tensor(0.0520)
# None  mean  tensor(26.3563)  max  tensor(40.)  median  tensor(26.)  min  tensor(21.)  ent  tensor(0.0578)
# None  mean  tensor(26.4150)  max  tensor(40.)  median  tensor(26.)  min  tensor(21.)  ent  tensor(0.0639)
# None  mean  tensor(26.4657)  max  tensor(40.)  median  tensor(26.)  min  tensor(20.)  ent  tensor(0.0659)
# None  mean  tensor(19.4087)  max  tensor(35.)  median  tensor(20.)  min  tensor(6.)  ent  tensor(1.5702)
# None  mean  tensor(22.8017)  max  tensor(36.)  median  tensor(22.)  min  tensor(15.)  ent  tensor(0.9705)
# None  mean  tensor(24.5823)  max  tensor(37.)  median  tensor(24.)  min  tensor(10.)  ent  tensor(1.1573)
# None  mean  tensor(21.5730)  max  tensor(36.)  median  tensor(22.)  min  tensor(6.)  ent  tensor(1.1748)
# None  mean  tensor(23.9670)  max  tensor(48.)  median  tensor(24.)  min  tensor(7.)  ent  tensor(1.1703)
# None  mean  tensor(25.5333)  max  tensor(41.)  median  tensor(25.)  min  tensor(10.)  ent  tensor(1.2017)
# None  mean  tensor(26.7660)  max  tensor(47.)  median  tensor(26.)  min  tensor(15.)  ent  tensor(1.1788)
# None  mean  tensor(28.6457)  max  tensor(46.)  median  tensor(27.)  min  tensor(15.)  ent  tensor(1.0583)
# None  mean  tensor(28.8947)  max  tensor(43.)  median  tensor(30.)  min  tensor(12.)  ent  tensor(0.9076)
# None  mean  tensor(29.0603)  max  tensor(44.)  median  tensor(30.)  min  tensor(14.)  ent  tensor(0.8135)
# None  mean  tensor(29.8097)  max  tensor(45.)  median  tensor(31.)  min  tensor(11.)  ent  tensor(0.7863)
# None  mean  tensor(30.5283)  max  tensor(45.)  median  tensor(32.)  min  tensor(10.)  ent  tensor(0.7852)
# None  mean  tensor(31.9063)  max  tensor(48.)  median  tensor(34.)  min  tensor(14.)  ent  tensor(0.7932)
# None  mean  tensor(32.6523)  max  tensor(48.)  median  tensor(34.)  min  tensor(13.)  ent  tensor(0.7958)
# None  mean  tensor(32.1957)  max  tensor(48.)  median  tensor(32.)  min  tensor(13.)  ent  tensor(0.7833)
# None  mean  tensor(31.2603)  max  tensor(48.)  median  tensor(29.)  min  tensor(15.)  ent  tensor(0.7521)
# None  mean  tensor(29.7257)  max  tensor(49.)  median  tensor(27.)  min  tensor(14.)  ent  tensor(0.7045)
# None  mean  tensor(28.6610)  max  tensor(46.)  median  tensor(26.)  min  tensor(14.)  ent  tensor(0.6553)
# None  mean  tensor(28.6527)  max  tensor(46.)  median  tensor(26.)  min  tensor(13.)  ent  tensor(0.6155)
# None  mean  tensor(28.4517)  max  tensor(44.)  median  tensor(26.)  min  tensor(13.)  ent  tensor(0.6016)
# None  mean  tensor(28.1640)  max  tensor(45.)  median  tensor(26.)  min  tensor(13.)  ent  tensor(0.6151)
# None  mean  tensor(27.5573)  max  tensor(46.)  median  tensor(26.)  min  tensor(14.)  ent  tensor(0.6651)
# None  mean  tensor(26.9133)  max  tensor(47.)  median  tensor(26.)  min  tensor(13.)  ent  tensor(0.7146)
# None  mean  tensor(26.5930)  max  tensor(46.)  median  tensor(26.)  min  tensor(13.)  ent  tensor(0.7408)
# None  mean  tensor(26.7600)  max  tensor(46.)  median  tensor(26.)  min  tensor(15.)  ent  tensor(0.7529)
# None  mean  tensor(27.7007)  max  tensor(50.)  median  tensor(26.)  min  tensor(17.)  ent  tensor(0.7531)
# None  mean  tensor(29.4810)  max  tensor(51.)  median  tensor(27.)  min  tensor(14.)  ent  tensor(0.7244)
# None  mean  tensor(32.7663)  max  tensor(50.)  median  tensor(31.)  min  tensor(17.)  ent  tensor(0.6611)
# None  mean  tensor(35.2517)  max  tensor(47.)  median  tensor(37.)  min  tensor(17.)  ent  tensor(0.5846)
# None  mean  tensor(36.3077)  max  tensor(47.)  median  tensor(38.)  min  tensor(16.)  ent  tensor(0.5211)
# None  mean  tensor(36.6013)  max  tensor(46.)  median  tensor(38.)  min  tensor(20.)  ent  tensor(0.4727)
# None  mean  tensor(36.4187)  max  tensor(45.)  median  tensor(37.)  min  tensor(18.)  ent  tensor(0.4346)
# None  mean  tensor(36.8500)  max  tensor(46.)  median  tensor(38.)  min  tensor(18.)  ent  tensor(0.4091)
# None  mean  tensor(36.7703)  max  tensor(46.)  median  tensor(38.)  min  tensor(17.)  ent  tensor(0.3883)
# None  mean  tensor(37.4820)  max  tensor(46.)  median  tensor(39.)  min  tensor(19.)  ent  tensor(0.3836)
# None  mean  tensor(37.8727)  max  tensor(45.)  median  tensor(39.)  min  tensor(17.)  ent  tensor(0.3923)
# None  mean  tensor(38.5720)  max  tensor(45.)  median  tensor(40.)  min  tensor(19.)  ent  tensor(0.4059)
# None  mean  tensor(39.2073)  max  tensor(45.)  median  tensor(41.)  min  tensor(19.)  ent  tensor(0.4254)
# None  mean  tensor(39.6820)  max  tensor(46.)  median  tensor(41.)  min  tensor(19.)  ent  tensor(0.4424)
# None  mean  tensor(39.6660)  max  tensor(46.)  median  tensor(41.)  min  tensor(18.)  ent  tensor(0.4571)
# None  mean  tensor(39.7217)  max  tensor(46.)  median  tensor(41.)  min  tensor(17.)  ent  tensor(0.4566)
# None  mean  tensor(39.5197)  max  tensor(45.)  median  tensor(41.)  min  tensor(15.)  ent  tensor(0.4422)
# None  mean  tensor(39.4387)  max  tensor(46.)  median  tensor(41.)  min  tensor(17.)  ent  tensor(0.4270)
# None  mean  tensor(39.6557)  max  tensor(44.)  median  tensor(41.)  min  tensor(19.)  ent  tensor(0.4296)
# None  mean  tensor(39.7050)  max  tensor(45.)  median  tensor(41.)  min  tensor(18.)  ent  tensor(0.4416)
# None  mean  tensor(39.9030)  max  tensor(45.)  median  tensor(41.)  min  tensor(17.)  ent  tensor(0.4553)
# None  mean  tensor(40.0890)  max  tensor(45.)  median  tensor(42.)  min  tensor(22.)  ent  tensor(0.4644)
# None  mean  tensor(40.0810)  max  tensor(46.)  median  tensor(42.)  min  tensor(17.)  ent  tensor(0.4591)
# None  mean  tensor(40.0433)  max  tensor(45.)  median  tensor(42.)  min  tensor(14.)  ent  tensor(0.4466)
# None  mean  tensor(39.8000)  max  tensor(45.)  median  tensor(41.)  min  tensor(17.)  ent  tensor(0.4442)
# None  mean  tensor(39.8130)  max  tensor(46.)  median  tensor(42.)  min  tensor(18.)  ent  tensor(0.4589)
# None  mean  tensor(39.8390)  max  tensor(46.)  median  tensor(42.)  min  tensor(22.)  ent  tensor(0.4770)
# None  mean  tensor(39.2430)  max  tensor(46.)  median  tensor(41.)  min  tensor(15.)  ent  tensor(0.4816)
# None  mean  tensor(38.8353)  max  tensor(46.)  median  tensor(41.)  min  tensor(18.)  ent  tensor(0.4745)
# None  mean  tensor(36.7960)  max  tensor(44.)  median  tensor(38.)  min  tensor(19.)  ent  tensor(0.4502)
# None  mean  tensor(36.6933)  max  tensor(45.)  median  tensor(38.)  min  tensor(17.)  ent  tensor(0.4060)
# None  mean  tensor(36.6990)  max  tensor(44.)  median  tensor(38.)  min  tensor(16.)  ent  tensor(0.3951)
# None  mean  tensor(36.4503)  max  tensor(44.)  median  tensor(38.)  min  tensor(19.)  ent  tensor(0.4481)
# None  mean  tensor(36.0540)  max  tensor(44.)  median  tensor(38.)  min  tensor(18.)  ent  tensor(0.4865)
# None  mean  tensor(35.8247)  max  tensor(44.)  median  tensor(38.)  min  tensor(15.)  ent  tensor(0.4708)
# None  mean  tensor(35.0853)  max  tensor(44.)  median  tensor(37.)  min  tensor(18.)  ent  tensor(0.4589)
# None  mean  tensor(32.9450)  max  tensor(44.)  median  tensor(37.)  min  tensor(18.)  ent  tensor(0.4960)
# None  mean  tensor(29.6293)  max  tensor(42.)  median  tensor(27.)  min  tensor(18.)  ent  tensor(0.5192)
# None  mean  tensor(27.7920)  max  tensor(40.)  median  tensor(27.)  min  tensor(18.)  ent  tensor(0.4446)
# None  mean  tensor(27.5573)  max  tensor(42.)  median  tensor(27.)  min  tensor(18.)  ent  tensor(0.4004)
# None  mean  tensor(27.8677)  max  tensor(44.)  median  tensor(27.)  min  tensor(15.)  ent  tensor(0.4132)
# None  mean  tensor(29.2023)  max  tensor(44.)  median  tensor(28.)  min  tensor(19.)  ent  tensor(0.4451)
# None  mean  tensor(30.9417)  max  tensor(45.)  median  tensor(30.)  min  tensor(15.)  ent  tensor(0.4546)
# None  mean  tensor(30.6797)  max  tensor(44.)  median  tensor(30.)  min  tensor(19.)  ent  tensor(0.4409)
# None  mean  tensor(30.6943)  max  tensor(45.)  median  tensor(31.)  min  tensor(18.)  ent  tensor(0.4164)
# None  mean  tensor(29.7310)  max  tensor(44.)  median  tensor(31.)  min  tensor(18.)  ent  tensor(0.3246)
# None  mean  tensor(29.8323)  max  tensor(45.)  median  tensor(31.)  min  tensor(18.)  ent  tensor(0.2961)
# None  mean  tensor(28.5560)  max  tensor(44.)  median  tensor(26.)  min  tensor(16.)  ent  tensor(0.3181)
# None  mean  tensor(29.8850)  max  tensor(44.)  median  tensor(26.)  min  tensor(19.)  ent  tensor(0.3641)
# None  mean  tensor(30.9887)  max  tensor(44.)  median  tensor(26.)  min  tensor(15.)  ent  tensor(0.3857)
# None  mean  tensor(32.3633)  max  tensor(44.)  median  tensor(30.)  min  tensor(19.)  ent  tensor(0.3854)
# None  mean  tensor(31.6430)  max  tensor(44.)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0.3747)
# None  mean  tensor(30.9820)  max  tensor(43.)  median  tensor(26.)  min  tensor(19.)  ent  tensor(0.3547)
# None  mean  tensor(29.6477)  max  tensor(43.)  median  tensor(26.)  min  tensor(19.)  ent  tensor(0.3219)
# None  mean  tensor(29.1203)  max  tensor(42.)  median  tensor(26.)  min  tensor(19.)  ent  tensor(0.2930)
# None  mean  tensor(28.1253)  max  tensor(42.)  median  tensor(26.)  min  tensor(15.)  ent  tensor(0.2521)
# None  mean  tensor(27.5560)  max  tensor(43.)  median  tensor(26.)  min  tensor(16.)  ent  tensor(0.2191)
# None  mean  tensor(27.1783)  max  tensor(41.)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0.1908)
# None  mean  tensor(26.9397)  max  tensor(42.)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0.1665)
# None  mean  tensor(26.7473)  max  tensor(41.)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0.1459)
# None  mean  tensor(26.7450)  max  tensor(40.)  median  tensor(26.)  min  tensor(19.)  ent  tensor(0.1349)
# None  mean  tensor(26.6660)  max  tensor(40.)  median  tensor(26.)  min  tensor(17.)  ent  tensor(0.1219)
# None  mean  tensor(26.6140)  max  tensor(41.)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0.1139)
# None  mean  tensor(26.6437)  max  tensor(42.)  median  tensor(26.)  min  tensor(22.)  ent  tensor(0.1102)
# None  mean  tensor(26.5687)  max  tensor(41.)  median  tensor(26.)  min  tensor(20.)  ent  tensor(0.1049)
# None  mean  tensor(26.5527)  max  tensor(41.)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0.1048)
# None  mean  tensor(26.4607)  max  tensor(44.)  median  tensor(26.)  min  tensor(20.)  ent  tensor(0.1104)
# None  mean  tensor(26.5327)  max  tensor(42.)  median  tensor(26.)  min  tensor(19.)  ent  tensor(0.1208)
# None  mean  tensor(26.4270)  max  tensor(40.)  median  tensor(26.)  min  tensor(22.)  ent  tensor(0.1295)
# None  mean  tensor(26.4960)  max  tensor(44.)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0.1319)
# None  mean  tensor(26.4647)  max  tensor(41.)  median  tensor(26.)  min  tensor(20.)  ent  tensor(0.1334)
# None  mean  tensor(26.5213)  max  tensor(41.)  median  tensor(26.)  min  tensor(19.)  ent  tensor(0.1258)
# None  mean  tensor(26.5437)  max  tensor(41.)  median  tensor(26.)  min  tensor(22.)  ent  tensor(0.1145)
# None  mean  tensor(26.5147)  max  tensor(40.)  median  tensor(26.)  min  tensor(19.)  ent  tensor(0.0999)
# None  mean  tensor(26.6150)  max  tensor(40.)  median  tensor(26.)  min  tensor(19.)  ent  tensor(0.0864)
# None  mean  tensor(26.6700)  max  tensor(41.)  median  tensor(26.)  min  tensor(19.)  ent  tensor(0.0822)
# None  mean  tensor(26.7303)  max  tensor(41.)  median  tensor(26.)  min  tensor(19.)  ent  tensor(0.0831)
# None  mean  tensor(26.7780)  max  tensor(41.)  median  tensor(26.)  min  tensor(20.)  ent  tensor(0.0841)
# None  mean  tensor(26.8860)  max  tensor(42.)  median  tensor(26.)  min  tensor(19.)  ent  tensor(0.0979)
# None  mean  tensor(26.9540)  max  tensor(44.)  median  tensor(26.)  min  tensor(19.)  ent  tensor(0.1069)
# None  mean  tensor(27.0993)  max  tensor(44.)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0.1182)
# None  mean  tensor(27.2717)  max  tensor(42.)  median  tensor(26.)  min  tensor(20.)  ent  tensor(0.1292)
# None  mean  tensor(27.4937)  max  tensor(44.)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0.1475)
# None  mean  tensor(27.8347)  max  tensor(42.)  median  tensor(26.)  min  tensor(20.)  ent  tensor(0.1721)
# None  mean  tensor(28.3637)  max  tensor(44.)  median  tensor(28.)  min  tensor(20.)  ent  tensor(0.1981)
# None  mean  tensor(28.9430)  max  tensor(44.)  median  tensor(30.)  min  tensor(19.)  ent  tensor(0.2413)
# None  mean  tensor(29.9797)  max  tensor(46.)  median  tensor(30.)  min  tensor(22.)  ent  tensor(0.3084)
# None  mean  tensor(33.0633)  max  tensor(46.)  median  tensor(30.)  min  tensor(20.)  ent  tensor(0.4373)
# None  mean  tensor(32.5017)  max  tensor(47.)  median  tensor(30.)  min  tensor(22.)  ent  tensor(0.5248)
# None  mean  tensor(30.6093)  max  tensor(47.)  median  tensor(30.)  min  tensor(19.)  ent  tensor(0.4510)
# None  mean  tensor(30.8713)  max  tensor(47.)  median  tensor(30.)  min  tensor(22.)  ent  tensor(0.4531)
# None  mean  tensor(35.0730)  max  tensor(48.)  median  tensor(38.)  min  tensor(23.)  ent  tensor(0.5322)
# None  mean  tensor(35.7867)  max  tensor(46.)  median  tensor(39.)  min  tensor(19.)  ent  tensor(0.5335)
# None  mean  tensor(33.1813)  max  tensor(46.)  median  tensor(30.)  min  tensor(19.)  ent  tensor(0.5351)
# None  mean  tensor(32.8143)  max  tensor(48.)  median  tensor(30.)  min  tensor(18.)  ent  tensor(0.5171)
# None  mean  tensor(33.3160)  max  tensor(47.)  median  tensor(30.)  min  tensor(19.)  ent  tensor(0.5264)
# None  mean  tensor(33.3390)  max  tensor(46.)  median  tensor(30.)  min  tensor(22.)  ent  tensor(0.5182)
# None  mean  tensor(31.9977)  max  tensor(46.)  median  tensor(30.)  min  tensor(25.)  ent  tensor(0.4565)
# None  mean  tensor(30.2877)  max  tensor(47.)  median  tensor(30.)  min  tensor(23.)  ent  tensor(0.3165)
# None  mean  tensor(30.2633)  max  tensor(45.)  median  tensor(30.)  min  tensor(25.)  ent  tensor(0.3288)
# None  mean  tensor(30.5623)  max  tensor(47.)  median  tensor(30.)  min  tensor(24.)  ent  tensor(0.3918)
# None  mean  tensor(31.4707)  max  tensor(46.)  median  tensor(30.)  min  tensor(22.)  ent  tensor(0.4522)
# None  mean  tensor(32.2570)  max  tensor(46.)  median  tensor(30.)  min  tensor(23.)  ent  tensor(0.4718)
# None  mean  tensor(32.7280)  max  tensor(46.)  median  tensor(30.)  min  tensor(21.)  ent  tensor(0.4799)
# None  mean  tensor(33.5030)  max  tensor(47.)  median  tensor(30.)  min  tensor(23.)  ent  tensor(0.4841)
# None  mean  tensor(33.8597)  max  tensor(46.)  median  tensor(30.)  min  tensor(23.)  ent  tensor(0.4861)
# None  mean  tensor(34.2267)  max  tensor(46.)  median  tensor(30.)  min  tensor(22.)  ent  tensor(0.4743)
# None  mean  tensor(33.3447)  max  tensor(47.)  median  tensor(30.)  min  tensor(19.)  ent  tensor(0.4577)
# None  mean  tensor(32.4477)  max  tensor(48.)  median  tensor(30.)  min  tensor(21.)  ent  tensor(0.4314)
# None  mean  tensor(31.5933)  max  tensor(46.)  median  tensor(30.)  min  tensor(23.)  ent  tensor(0.4012)
# None  mean  tensor(30.9093)  max  tensor(45.)  median  tensor(30.)  min  tensor(23.)  ent  tensor(0.3668)
# None  mean  tensor(30.7467)  max  tensor(45.)  median  tensor(30.)  min  tensor(22.)  ent  tensor(0.3400)
# None  mean  tensor(30.5373)  max  tensor(45.)  median  tensor(30.)  min  tensor(22.)  ent  tensor(0.3266)
# None  mean  tensor(30.7140)  max  tensor(44.)  median  tensor(30.)  min  tensor(24.)  ent  tensor(0.3453)
# None  mean  tensor(30.3387)  max  tensor(44.)  median  tensor(30.)  min  tensor(22.)  ent  tensor(0.3056)
# None  mean  tensor(17.7773)  max  tensor(34.)  median  tensor(17.)  min  tensor(7.)  ent  tensor(1.5977)
# None  mean  tensor(22.3047)  max  tensor(38.)  median  tensor(23.)  min  tensor(8.)  ent  tensor(1.4045)
# None  mean  tensor(24.3640)  max  tensor(41.)  median  tensor(24.)  min  tensor(11.)  ent  tensor(1.1667)
# None  mean  tensor(25.2433)  max  tensor(39.)  median  tensor(25.)  min  tensor(10.)  ent  tensor(1.1504)
# None  mean  tensor(23.3247)  max  tensor(35.)  median  tensor(24.)  min  tensor(6.)  ent  tensor(0.9765)
# None  mean  tensor(24.2243)  max  tensor(35.)  median  tensor(25.)  min  tensor(8.)  ent  tensor(0.9481)
# None  mean  tensor(25.7700)  max  tensor(40.)  median  tensor(26.)  min  tensor(8.)  ent  tensor(1.0657)
# None  mean  tensor(29.1660)  max  tensor(47.)  median  tensor(28.)  min  tensor(13.)  ent  tensor(1.1119)
# None  mean  tensor(33.4143)  max  tensor(49.)  median  tensor(35.)  min  tensor(17.)  ent  tensor(0.9765)
# None  mean  tensor(33.6510)  max  tensor(48.)  median  tensor(35.)  min  tensor(16.)  ent  tensor(0.8248)
# None  mean  tensor(34.1913)  max  tensor(49.)  median  tensor(36.)  min  tensor(16.)  ent  tensor(0.7755)
# None  mean  tensor(35.2820)  max  tensor(50.)  median  tensor(37.)  min  tensor(15.)  ent  tensor(0.7735)
# None  mean  tensor(36.9907)  max  tensor(50.)  median  tensor(39.)  min  tensor(17.)  ent  tensor(0.7610)
# None  mean  tensor(38.1777)  max  tensor(49.)  median  tensor(40.)  min  tensor(15.)  ent  tensor(0.7225)
# None  mean  tensor(38.4517)  max  tensor(52.)  median  tensor(40.)  min  tensor(16.)  ent  tensor(0.6686)
# None  mean  tensor(38.7150)  max  tensor(48.)  median  tensor(40.)  min  tensor(18.)  ent  tensor(0.6137)
# None  mean  tensor(38.9957)  max  tensor(48.)  median  tensor(41.)  min  tensor(20.)  ent  tensor(0.5784)
# None  mean  tensor(39.4073)  max  tensor(49.)  median  tensor(41.)  min  tensor(18.)  ent  tensor(0.5677)
# None  mean  tensor(39.6290)  max  tensor(48.)  median  tensor(42.)  min  tensor(18.)  ent  tensor(0.5666)
# None  mean  tensor(39.7303)  max  tensor(48.)  median  tensor(42.)  min  tensor(18.)  ent  tensor(0.5569)
# None  mean  tensor(39.8797)  max  tensor(48.)  median  tensor(42.)  min  tensor(18.)  ent  tensor(0.5370)
# None  mean  tensor(39.1553)  max  tensor(47.)  median  tensor(40.)  min  tensor(17.)  ent  tensor(0.5227)
# None  mean  tensor(39.2917)  max  tensor(47.)  median  tensor(40.)  min  tensor(21.)  ent  tensor(0.5147)
# None  mean  tensor(39.2573)  max  tensor(47.)  median  tensor(40.)  min  tensor(22.)  ent  tensor(0.5189)
# None  mean  tensor(39.2737)  max  tensor(47.)  median  tensor(40.)  min  tensor(20.)  ent  tensor(0.5241)
# None  mean  tensor(39.0573)  max  tensor(47.)  median  tensor(40.)  min  tensor(20.)  ent  tensor(0.5141)
# None  mean  tensor(39.2880)  max  tensor(47.)  median  tensor(40.)  min  tensor(23.)  ent  tensor(0.5121)
# None  mean  tensor(39.0530)  max  tensor(47.)  median  tensor(40.)  min  tensor(21.)  ent  tensor(0.5134)
# None  mean  tensor(38.9207)  max  tensor(47.)  median  tensor(40.)  min  tensor(22.)  ent  tensor(0.5018)
# None  mean  tensor(38.9333)  max  tensor(46.)  median  tensor(40.)  min  tensor(22.)  ent  tensor(0.4925)
# None  mean  tensor(38.8667)  max  tensor(48.)  median  tensor(40.)  min  tensor(23.)  ent  tensor(0.5085)
# None  mean  tensor(39.5853)  max  tensor(48.)  median  tensor(42.)  min  tensor(23.)  ent  tensor(0.5152)
# ...
# None  mean  tensor(23.9637)  max  tensor(24.)  median  tensor(24.)  min  tensor(19.)  ent  tensor(0.0366)
# None  mean  tensor(23.9760)  max  tensor(24.)  median  tensor(24.)  min  tensor(19.)  ent  tensor(0.0365)
# None  mean  tensor(23.9837)  max  tensor(28.)  median  tensor(24.)  min  tensor(19.)  ent  tensor(0.0364)
# None  mean  tensor(23.9717)  max  tensor(28.)  median  tensor(24.)  min  tensor(19.)  ent  tensor(0.0363)
# None  mean  tensor(23.9717)  max  tensor(24.)  median  tensor(24.)  min  tensor(19.)  ent  tensor(0.0362)
# None  mean  tensor(23.9790)  max  tensor(24.)  median  tensor(24.)  min  tensor(19.)  ent  tensor(0.0361)
# None  mean  tensor(23.9847)  max  tensor(24.)  median  tensor(24.)  min  tensor(19.)  ent  tensor(0.0359)
# None  mean  tensor(23.9703)  max  tensor(24.)  median  tensor(24.)  min  tensor(19.)  ent  tensor(0.0359)
# None  mean  tensor(23.9837)  max  tensor(24.)  median  tensor(24.)  min  tensor(19.)  ent  tensor(0.0357)
# None  mean  tensor(23.9753)  max  tensor(32.)  median  tensor(24.)  min  tensor(19.)  ent  tensor(0.0357)
# None  mean  tensor(18.6040)  max  tensor(36.)  median  tensor(19.)  min  tensor(6.)  ent  tensor(1.5915)
# None  mean  tensor(23.7463)  max  tensor(35.)  median  tensor(24.)  min  tensor(16.)  ent  tensor(1.1296)
# None  mean  tensor(25.4570)  max  tensor(37.)  median  tensor(25.)  min  tensor(15.)  ent  tensor(1.2503)
# None  mean  tensor(25.1680)  max  tensor(37.)  median  tensor(25.)  min  tensor(8.)  ent  tensor(1.2973)
# None  mean  tensor(25.8597)  max  tensor(38.)  median  tensor(26.)  min  tensor(6.)  ent  tensor(1.2734)
# None  mean  tensor(27.2507)  max  tensor(44.)  median  tensor(28.)  min  tensor(8.)  ent  tensor(1.2251)
# None  mean  tensor(29.3797)  max  tensor(49.)  median  tensor(29.)  min  tensor(13.)  ent  tensor(1.1348)
# None  mean  tensor(31.5850)  max  tensor(48.)  median  tensor(31.)  min  tensor(12.)  ent  tensor(0.9904)
# None  mean  tensor(29.4870)  max  tensor(47.)  median  tensor(29.)  min  tensor(10.)  ent  tensor(0.7812)
# None  mean  tensor(27.1427)  max  tensor(45.)  median  tensor(26.)  min  tensor(10.)  ent  tensor(0.6277)
# None  mean  tensor(26.9447)  max  tensor(44.)  median  tensor(26.)  min  tensor(10.)  ent  tensor(0.5461)
# None  mean  tensor(29.2273)  max  tensor(45.)  median  tensor(27.)  min  tensor(10.)  ent  tensor(0.5348)
# None  mean  tensor(33.2913)  max  tensor(47.)  median  tensor(35.)  min  tensor(12.)  ent  tensor(0.5813)
# None  mean  tensor(36.5437)  max  tensor(49.)  median  tensor(38.)  min  tensor(13.)  ent  tensor(0.6345)
# None  mean  tensor(37.7210)  max  tensor(47.)  median  tensor(39.)  min  tensor(14.)  ent  tensor(0.6383)
# None  mean  tensor(38.0037)  max  tensor(46.)  median  tensor(39.)  min  tensor(18.)  ent  tensor(0.5962)
# None  mean  tensor(37.7177)  max  tensor(46.)  median  tensor(39.)  min  tensor(19.)  ent  tensor(0.5212)
# None  mean  tensor(37.0167)  max  tensor(46.)  median  tensor(38.)  min  tensor(14.)  ent  tensor(0.4423)
# None  mean  tensor(36.3097)  max  tensor(45.)  median  tensor(37.)  min  tensor(18.)  ent  tensor(0.3897)
# None  mean  tensor(36.3043)  max  tensor(45.)  median  tensor(37.)  min  tensor(17.)  ent  tensor(0.3690)
# None  mean  tensor(36.6647)  max  tensor(44.)  median  tensor(38.)  min  tensor(16.)  ent  tensor(0.3780)
# None  mean  tensor(37.5850)  max  tensor(45.)  median  tensor(38.)  min  tensor(16.)  ent  tensor(0.4106)
# None  mean  tensor(38.2777)  max  tensor(46.)  median  tensor(39.)  min  tensor(16.)  ent  tensor(0.4539)
# None  mean  tensor(38.7207)  max  tensor(45.)  median  tensor(40.)  min  tensor(20.)  ent  tensor(0.4866)
# None  mean  tensor(39.2407)  max  tensor(46.)  median  tensor(40.)  min  tensor(21.)  ent  tensor(0.4996)
# None  mean  tensor(39.1330)  max  tensor(47.)  median  tensor(40.)  min  tensor(16.)  ent  tensor(0.4819)
# None  mean  tensor(38.3400)  max  tensor(45.)  median  tensor(39.)  min  tensor(18.)  ent  tensor(0.4539)
# None  mean  tensor(37.9577)  max  tensor(46.)  median  tensor(39.)  min  tensor(17.)  ent  tensor(0.4212)
# None  mean  tensor(37.5580)  max  tensor(45.)  median  tensor(38.)  min  tensor(15.)  ent  tensor(0.3962)
# None  mean  tensor(37.5287)  max  tensor(44.)  median  tensor(38.)  min  tensor(15.)  ent  tensor(0.3913)
# None  mean  tensor(38.1383)  max  tensor(44.)  median  tensor(39.)  min  tensor(17.)  ent  tensor(0.4052)
# None  mean  tensor(38.5923)  max  tensor(45.)  median  tensor(39.)  min  tensor(16.)  ent  tensor(0.4344)
# None  mean  tensor(38.9293)  max  tensor(44.)  median  tensor(40.)  min  tensor(17.)  ent  tensor(0.4651)
# None  mean  tensor(39.7520)  max  tensor(45.)  median  tensor(41.)  min  tensor(23.)  ent  tensor(0.4765)
# None  mean  tensor(39.8493)  max  tensor(46.)  median  tensor(41.)  min  tensor(24.)  ent  tensor(0.4765)
# None  mean  tensor(39.7010)  max  tensor(46.)  median  tensor(41.)  min  tensor(17.)  ent  tensor(0.4667)
# None  mean  tensor(39.5463)  max  tensor(45.)  median  tensor(41.)  min  tensor(17.)  ent  tensor(0.4535)
# None  mean  tensor(39.5850)  max  tensor(45.)  median  tensor(41.)  min  tensor(19.)  ent  tensor(0.4447)
# None  mean  tensor(39.6253)  max  tensor(46.)  median  tensor(41.)  min  tensor(22.)  ent  tensor(0.4638)
# None  mean  tensor(39.3587)  max  tensor(46.)  median  tensor(42.)  min  tensor(19.)  ent  tensor(0.4865)
# None  mean  tensor(38.9000)  max  tensor(45.)  median  tensor(41.)  min  tensor(19.)  ent  tensor(0.4796)
# None  mean  tensor(38.6853)  max  tensor(44.)  median  tensor(41.)  min  tensor(23.)  ent  tensor(0.4744)
# None  mean  tensor(37.4550)  max  tensor(45.)  median  tensor(41.)  min  tensor(19.)  ent  tensor(0.4861)
# None  mean  tensor(35.9360)  max  tensor(46.)  median  tensor(32.)  min  tensor(19.)  ent  tensor(0.4926)
# None  mean  tensor(35.1097)  max  tensor(45.)  median  tensor(32.)  min  tensor(19.)  ent  tensor(0.4804)
# None  mean  tensor(34.9133)  max  tensor(47.)  median  tensor(32.)  min  tensor(19.)  ent  tensor(0.4757)
# None  mean  tensor(32.8033)  max  tensor(45.)  median  tensor(31.)  min  tensor(15.)  ent  tensor(0.4667)
# None  mean  tensor(31.8537)  max  tensor(44.)  median  tensor(30.)  min  tensor(22.)  ent  tensor(0.4325)
# None  mean  tensor(30.6257)  max  tensor(44.)  median  tensor(30.)  min  tensor(19.)  ent  tensor(0.3983)
# None  mean  tensor(29.5853)  max  tensor(44.)  median  tensor(26.)  min  tensor(22.)  ent  tensor(0.3566)
# None  mean  tensor(29.2273)  max  tensor(44.)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0
)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0.2072)
# None  mean  tensor(28.1960)  max  tensor(40.)  median  tensor(26.)  min  tensor(23.)  ent  tensor(0.2696)
# None  mean  tensor(28.4183)  max  tensor(42.)  median  tensor(26.)  min  tensor(22.)  ent  tensor(0.3154)
# None  mean  tensor(28.4363)  max  tensor(43.)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0.3274)
# None  mean  tensor(28.3907)  max  tensor(40.)  median  tensor(26.)  min  tensor(18.)  ent  tensor(0.3253)
# None  mean  tensor(28.1097)  max  tensor(40.)  median  tensor(26.)  min  tensor(22.)  ent  tensor(0.3286)
# None  mean  tensor(27.9247)  max  tensor(44.)  median  tensor(26.)  min  tensor(19.)  ent  tensor(0.3371)
# None  mean  tensor(27.9060)  max  tensor(41.)  median  tensor(26.)  min  tensor(22.)  ent  tensor(0.3460)
# None  mean  tensor(27.9317)  max  tensor(44.)  median  tensor(26.)  min  tensor(19.)  ent  tensor(0.3472)
# None  mean  tensor(27.9803)  max  tensor(44.)  median  tensor(26.)  min  tensor(22.)  ent  tensor(0.3402)
# None  mean  tensor(28.1747)  max  tensor(43.)  median  tensor(26.)  min  tensor(22.)  ent  tensor(0.3357)
# None  mean  tensor(28.3830)  max  tensor(44.)  median  tensor(26.)  min  tensor(22.)  ent  tensor(0.3365)
# None  mean  tensor(28.5483)  max  tensor(44.)  median  tensor(29.)  min  tensor(18.)  ent  tensor(0.3329)
# None  mean  tensor(28.5507)  max  tensor(44.)  median  tensor(29.)  min  tensor(23.)  ent  tensor(0.3226)
# None  mean  tensor(28.6533)  max  tensor(44.)  median  tensor(29.)  min  tensor(22.)  ent  tensor(0.3041)
# None  mean  tensor(28.7780)  max  tensor(44.)  median  tensor(29.)  min  tensor(22.)  ent  tensor(0.3069)
# None  mean  tensor(28.9397)  max  tensor(44.)  median  tensor(30.)  min  tensor(21.)  ent  tensor(0.3854)
# None  mean  tensor(29.0367)  max  tensor(44.)  median  tensor(30.)  min  tensor(22.)  ent  tensor(0.3654)
# None  mean  tensor(28.9353)  max  tensor(40.)  median  tensor(30.)  min  tensor(18.)  ent  tensor(0.3490)
# None  mean  tensor(28.6703)  max  tensor(44.)  median  tensor(30.)  min  tensor(24.)  ent  tensor(0.3741)
# None  mean  tensor(28.4787)  max  tensor(44.)  median  tensor(29.)  min  tensor(18.)  ent  tensor(0.3938)
# None  mean  tensor(28.6020)  max  tensor(44.)  median  tensor(30.)  min  tensor(21.)  ent  tensor(0.3925)
# None  mean  tensor(28.7920)  max  tensor(44.)  median  tensor(30.)  min  tensor(23.)  ent  tensor(0.3928)
# None  mean  tensor(29.0280)  max  tensor(43.)  median  tensor(30.)  min  tensor(23.)  ent  tensor(0.3921)
# None  mean  tensor(29.4360)  max  tensor(46.)  median  tensor(30.)  min  tensor(23.)  ent  tensor(0.3957)
# None  mean  tensor(29.5623)  max  tensor(44.)  median  tensor(30.)  min  tensor(20.)  ent  tensor(0.3964)
# None  mean  tensor(29.6060)  max  tensor(43.)  median  tensor(30.)  min  tensor(18.)  ent  tensor(0.3969)
# None  mean  tensor(29.5190)  max  tensor(44.)  median  tensor(30.)  min  tensor(21.)  ent  tensor(0.3939)
# None  mean  tensor(29.3867)  max  tensor(43.)  median  tensor(30.)  min  tensor(23.)  ent  tensor(0.3837)
# None  mean  tensor(29.2303)  max  tensor(44.)  median  tensor(30.)  min  tensor(22.)  ent  tensor(0.3741)
# None  mean  tensor(29.2160)  max  tensor(44.)  median  tensor(30.)  min  tensor(23.)  ent  tensor(0.3651)
# None  mean  tensor(29.1700)  max  tensor(44.)  median  tensor(30.)  min  tensor(23.)  ent  tensor(0.3626)
# None  mean  tensor(29.3120)  max  tensor(42.)  median  tensor(30.)  min  tensor(19.)  ent  tensor(0.3610)
# None  mean  tensor(29.5237)  max  tensor(42.)  median  tensor(30.)  min  tensor(23.)  ent  tensor(0.3607)
# None  mean  tensor(29.6683)  max  tensor(43.)  median  tensor(30.)  min  tensor(23.)  ent  tensor(0.3653)
# None  mean  tensor(29.8400)  max  tensor(44.)  median  tensor(30.)  min  tensor(19.)  ent  tensor(0.3692)
# None  mean  tensor(29.7940)  max  tensor(44.)  median  tensor(30.)  min  tensor(19.)  ent  tensor(0.3995)
# None  mean  tensor(30.7847)  max  tensor(45.)  median  tensor(30.)  min  tensor(23.)  ent  tensor(0.4420)
# None  mean  tensor(30.6540)  max  tensor(44.)  median  tensor(30.)  min  tensor(23.)  ent  tensor(0.3923)
# None  mean  tensor(30.0180)  max  tensor(44.)  median  tensor(30.)  min  tensor(24.)  ent  tensor(0.3741)
# None  mean  tensor(30.2167)  max  tensor(44.)  median  tensor(30.)  min  tensor(18.)  ent  tensor(0.3942)
# None  mean  tensor(30.9003)  max  tensor(44.)  median  tensor(30.)  min  tensor(24.)  ent  tensor(0.4404)
# None  mean  tensor(30.4843)  max  tensor(44.)  median  tensor(30.)  min  tensor(19.)  ent  tensor(0.4658)
# None  mean  tensor(30.3783)  max  tensor(44.)  median  tensor(30.)  min  tensor(19.)  ent  tensor(0.3728)
# None  mean  tensor(29.7917)  max  tensor(42.)  median  tensor(30.)  min  tensor(23.)  ent  tensor(0.1931)
# None  mean  tensor(30.4137)  max  tensor(44.)  median  tensor(29.)  min  tensor(23.)  ent  tensor(0.2808)
# None  mean  tensor(33.5903)  max  tensor(44.)  median  tensor(37.)  min  tensor(24.)  ent  tensor(0.4672)
# None  mean  tensor(30.9943)  max  tensor(44.)  median  tensor(28.)  min  tensor(18.)  ent  tensor(0.4001)
# min: 21.80±1.94, max: 41.70±4.96, mean: 28.90±2.80, median: 28.00±2.37

# %%
from tqdm import tqdm

def train_2():
    # Agent's policy
    if params["alg"]["type"]=="M" or params["alg"]["type"]=="SRL":
        agent = agent_net(2, env.action_dim)
    else:
        agent = agent_net(H-1, env.action_dim)
    optim = torch.optim.Adam(agent.parameters(), lr=params["alg"]["lr"])

    # 记录每个epoch的奖励
    epoch_rewards = []
    
    # 添加进度条
    epoch_bar = tqdm(range(epochs), desc="Training", unit="epoch")
    for t_eps in epoch_bar:
        mat_action = []
        mat_state = []
        mat_return = []
        marginal_return = []
        mat_done = []
        # print(t_eps)
        env.initialize()
        mat_state.append(env.state)
        init_state = env.state
        list_batch_state = []
        for h_iter in range(H-1):
            if params["alg"]["type"]=="M" or params["alg"]["type"]=="SRL":
                batch_state = mat_state[-1].reshape(-1, 1).float()
                # append time index to the state
                batch_state = torch.cat(
                    [batch_state, h_iter*torch.ones_like(batch_state)], 1)
            else:
                batch_state = append_state(mat_state, H-1)
            action_prob = agent(batch_state)
            policy_dist = Categorical(action_prob)
            actions = policy_dist.sample()
            mat_action.append(actions)
            env.step(h_iter, actions)
            mat_state.append(env.state)  # s+1
            mat_return.append(env.weighted_traj_return(mat_state, type = params["alg"]["type"]))
            if h_iter ==0:
                marginal_return.append(mat_return[h_iter])
            else:
                marginal_return.append(mat_return[h_iter] - mat_return[h_iter-1])
            list_batch_state.append(batch_state)

        ###################
        # Compute gradients
        ###################

        states_visited = torch.vstack(list_batch_state).float()
    
        policy_dist = Categorical(agent(states_visited))
        log_prob = policy_dist.log_prob(torch.hstack(mat_action))
        batch_return = torch.hstack(marginal_return)/MAX_Ret

        # - 2*policy_dist.entropy().mean()
        J_obj = -1*(torch.mean(log_prob*batch_return) + params["alg"]["ent_coef"] *
                    policy_dist.entropy().mean()/(t_eps+1))
        optim.zero_grad()
        J_obj.backward()
        optim.step()

        obj = env.weighted_traj_return(mat_state).float()
        current_reward_mean = obj.mean().item()
        epoch_rewards.append(current_reward_mean)
        
        # 更新进度条显示信息
        epoch_bar.set_postfix({
            'mean': f'{current_reward_mean:.3f}',
            'max': f'{obj.max():.3f}',
            'min': f'{obj.min():.3f}',
            'median': f'{obj.median():.3f}',
            'entropy': f'{policy_dist.entropy().mean().detach():.3f}'
        })
        
        # 注释掉原来的print语句
        # print(visu.JPi_optimal, " mean ", obj.mean(), " max ",
        #     obj.max(), " median ", obj.median(), " min ", obj.min(), " ent ", policy_dist.entropy().mean().detach())
    
    epoch_bar.close()
    
    return agent, epoch_rewards

# %%
min_return = []
max_return = []
mean_return = []
median_return = []
epoch_rewards_all = []
for iter in range(10):
    # params["common"]["batch_size"]=1000
    agent, epoch_rewards = train_2()
    epoch_rewards_all.append(epoch_rewards)
    mat_state = []
    mat_return = []
    env.initialize()
    mat_state.append(env.state)
    init_state = env.state
    for h_iter in range(H-1):
        batch_state = append_state(mat_state, H-1)
        action_prob = agent(batch_state)
        policy_dist = Categorical(action_prob)
        actions = policy_dist.sample()
        env.step(h_iter, actions)
        mat_state.append(env.state)  # s+1

    returns = env.weighted_traj_return(mat_state, type = params["alg"]["type"]).float()
    min_return.append(returns.min())
    max_return.append(returns.max())
    mean_return.append(returns.mean())
    median_return.append(returns.median())
mean_min_return = np.mean(min_return)
std_min_return = np.std(min_return)
mean_max_return = np.mean(max_return)
std_max_return = np.std(max_return)
mean_mean_return = np.mean(mean_return)
std_mean_return = np.std(mean_return)
mean_median_return = np.mean(median_return)
std_median_return = np.std(median_return)
print(f"min: {mean_min_return:.2f}±{std_min_return:.2f}, max: {mean_max_return:.2f}±{std_max_return:.2f}, mean: {mean_mean_return:.2f}±{std_mean_return:.2f}, median: {mean_median_return:.2f}±{std_median_return:.2f}")
# Out:
# Training: 100%|██████████| 140/140 [01:57<00:00,  1.19epoch/s, mean=23.732, max=36.000, min=18.000, median=24.000, entropy=0.745]
# Training: 100%|██████████| 140/140 [02:00<00:00,  1.16epoch/s, mean=26.928, max=29.000, min=19.000, median=27.000, entropy=0.012]
# Training: 100%|██████████| 140/140 [01:59<00:00,  1.17epoch/s, mean=28.023, max=40.000, min=24.000, median=29.000, entropy=0.337]
# Training: 100%|██████████| 140/140 [02:03<00:00,  1.13epoch/s, mean=29.489, max=41.000, min=24.000, median=28.000, entropy=0.341]
# Training: 100%|██████████| 140/140 [01:57<00:00,  1.19epoch/s, mean=23.965, max=24.000, min=19.000, median=24.000, entropy=0.023]
# Training: 100%|██████████| 140/140 [02:02<00:00,  1.14epoch/s, mean=34.562, max=46.000, min=28.000, median=35.000, entropy=0.660]
# Training: 100%|██████████| 140/140 [01:57<00:00,  1.20epoch/s, mean=23.970, max=24.000, min=19.000, median=24.000, entropy=0.016]
# Training: 100%|██████████| 140/140 [02:02<00:00,  1.14epoch/s, mean=31.783, max=32.000, min=20.000, median=32.000, entropy=0.013]
# Training: 100%|██████████| 140/140 [01:56<00:00,  1.20epoch/s, mean=23.990, max=36.000, min=19.000, median=24.000, entropy=0.389]
# Training: 100%|██████████| 140/140 [02:03<00:00,  1.13epoch/s, mean=31.976, max=44.000, min=24.000, median=32.000, entropy=0.326]
# min: 20.90±2.91, max: 35.80±7.92, mean: 27.82±3.68, median: 27.90±3.70

# %%
import matplotlib.pyplot as plt
iteration_list = list(range(len(epoch_rewards)))
plt.plot(iteration_list, epoch_rewards)
plt.xlabel('Iterations')
plt.ylabel('Returns')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 使用epoch_rewards_all计算均值和标准差
epoch_rewards_array = np.array(epoch_rewards_all)  # shape: (10, epochs)
mean_rewards = np.mean(epoch_rewards_array, axis=0)  # 每个epoch的均值
std_rewards = np.std(epoch_rewards_array, axis=0)   # 每个epoch的标准差

# 创建x轴（epoch数）
epochs_range = range(len(mean_rewards))

# 绘制均值±标准差图
plt.figure(figsize=(10, 6))
plt.plot(epochs_range, mean_rewards, 'b-', label='Mean', linewidth=2)
plt.fill_between(epochs_range, 
                 mean_rewards - std_rewards, 
                 mean_rewards + std_rewards, 
                 alpha=0.3, color='blue', label='±1 std')

plt.xlabel('Epochs')
plt.ylabel('Returns')
plt.title('Training Progress: Mean ± Standard Deviation (10 runs)')
# plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# 打印一些统计信息
print(f"最终epoch的均值: {mean_rewards[-1]:.3f} ± {std_rewards[-1]:.3f}")
print(f"最大均值: {np.max(mean_rewards):.3f} (epoch {np.argmax(mean_rewards)})")
print(f"训练开始时均值: {mean_rewards[0]:.3f} ± {std_rewards[0]:.3f}")
# Out:
# 最终epoch的均值: 27.842 ± 3.783
# 最大均值: 31.456 (epoch 25)
# 训练开始时均值: 18.320 ± 0.990

# %%
import pickle

with open('two_room_98_data/epoch_rewards_subrl.pkl', 'wb') as f:
    pickle.dump(epoch_rewards_all, f)
print("epoch_rewards_all 已保存为 two_room_98_data/epoch_rewards_subrl.pkl")
# Out:
# epoch_rewards_all 已保存为 two_room_98_data/epoch_rewards_subrl.pkl
